# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
import glob

# %%
allFiles =glob.glob('*csv')

# %%
allFiles
# Out:
# ['Copy of Nakisa Weekly Report (02.07.2018).csv',
#  'Copy of Nakisa Weekly Report (15.01.2018).csv',
#  'Copy of Nakisa Weekly Report (26.02.2018).csv',
#  'Copy of Nakisa Weekly Report (26.03.2018).csv',
#  'Copy of Nakisa Weekly Report (27.08.2018).csv',
#  'Copy of Nakisa Weekly Report (30.04.2018).csv',
#  'Copy of Nakisa Weekly Report (30.05.2018).csv',
#  'Copy of Nakisa Weekly Report (30.07.2018).csv',
#  'Nakisa Weekly Report (01 05 2017).csv',
#  'Nakisa Weekly Report (25.09.2017).csv',
#  'Nakisa Weekly Report (26.06.2017).csv',
#  'Nakisa Weekly Report (27 02 2017) HR0781387.csv',
#  'Nakisa Weekly Report (27.03.2017).csv',
#  'Nakisa Weekly Report (27.11.2017).csv',
#  'Nakisa Weekly Report (27.12.2017).csv',
#  'Nakisa Weekly Report (28.08.2017).csv',
#  'Nakisa Weekly Report (29.05.2017).csv',
#  'Nakisa Weekly Report (30.01.2017).csv',
#  'Nakisa Weekly Report (30.10.2017).csv',
#  'Nakisa Weekly Report (31.07.2017).csv']

# %%
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0, encoding='latin')
    list_.append(df)
frame = pd.concat(list_)

# %%
frame
# Out:
#                    Company Code Company Code Id       Date    Date Detected  \
# 0        Rio Tinto Services Ltd            9040  30-Jun-18  9/16/2016 21:43
# 1        Rio Tinto Services Ltd            9040  30-Jun-18  9/16/2016 21:43
# 2        Rio Tinto Services Ltd            9040  30-Jun-18  9/16/2016 21:43
# 3     Rio Tinto SG Holdings P L            9630  30-Jun-18  9/16/2016 21:43
# 4     Rio Tinto SG Holdings P L            9630  30-Jun-18  9/16/2016 21:43
# 5          DNU RT Canada (R085)            B996  30-Jun-18  9/16/2016 21:43
# 6                      QMM S.A.            6170  30-Jun-18  9/16/2016 21:43
# 7      Pilbara Iron Co Serv P/L            3000  30-Jun-18  9/16/2016 21:43
# 8        RT (Shanghai) Co., Ltd            8500  30-Jun-18  9/16/2016 21:43
# 9             Rio Tinto Belgium            M397  30-Jun-18  9/16/2016 21:43
# 10         DNU RT Canada (R085)            B996  30-Jun-18  9/16/2016 21:43
# ...

# %%
frame.to_csv('nakisa.csv')
